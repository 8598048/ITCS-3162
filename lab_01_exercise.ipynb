# %% [markdown]
# # Lab 1 — Exercise: Notebooks & Markdown
#
# **ITCS 3162 — Introduction to Data Mining**
#
# **Name:** Sam Suther
# **Date:** May 24, 2026
#
# Complete the exercises below. For each task:
# - **Code tasks** → fill in the code cell
# - **Written answers** → edit the markdown cell directly (look for `YOUR ANSWER:` prompts)
#
# When you're done, run **Kernel → Restart & Run All** to make sure the whole notebook executes top-to-bottom without errors, then download the `.ipynb` and submit via Canvas.

# %% [markdown]
# ## Exercise 1 — Running cells (5 pts)
#
# Run the cell below. Then **modify** it so that it prints your full name and your major.

# %%
# TODO: change the strings to your name and major
name = "Sam Suther"
major = "Computer Science"
print(f"Hi, I'm {name} and I'm studying {major}.")

# %% [markdown]
# ## Exercise 2 — Variable persistence (10 pts)
#
# Write code in the next cell that creates two variables, `a` and `b`, with any numeric values you like. Then in the cell after that, print their sum, difference, and product on three separate lines.

# %%
# TODO: define a and b
a = 12
b = 7

# %%
# TODO: print a+b, a-b, a*b on separate lines
print(a + b)
print(a - b)
print(a * b)

# %% [markdown]
# ## Exercise 3 — Markdown formatting (15 pts)
#
# ## About me
#
# - Favorite class: Digital Forensics
# - Hobby: Keeping fish tanks
# - Goal for this course: Get comfortable working with real datasets and understand how mining algorithms actually work under the hood
#
# Data mining feels like a **natural extension** of the analytical side of security work, and I'm hoping it makes me a *more well-rounded* problem solver.
#
# One library I'll be using a lot this semester is `pandas`.
#
# A site I find useful: [Python Documentation](https://docs.python.org/3/)

# %% [markdown]
# ## Exercise 4 — Math notation (10 pts)
#
# $$
# y = mx + b
# $$
#
# In this equation, $m$ represents the slope of the line, which tells you how much $y$ changes for every one-unit increase in $x$.

# %% [markdown]
# ## Exercise 5 — A small table (10 pts)
#
# | Task | Type | Example use case |
# |---|---|---|
# | Classification | Supervised | Predicting whether an email is spam or not |
# | Clustering | Unsupervised | Grouping customers by purchasing behavior |
# | Association Rule Mining | Association | Finding that customers who buy bread often also buy butter |

# %% [markdown]
# ## Exercise 6 — Reflection (10 pts)
#
# One thing I found a little confusing at first was execution order — the fact that cells don't have to be run top-to-bottom means a variable can have a different value depending on what order you ran things, which can cause hard-to-track bugs. That said, notebooks are way more useful than a plain script when you're exploring data because you can run one small chunk at a time and immediately see the output without re-running everything. It makes it a lot easier to iterate and experiment without losing your place.

# %% [markdown]
# ## Submission checklist
#
# - [x] Replaced your name and date at the top
# - [x] All code cells run without errors
# - [x] All `YOUR ANSWER` prompts have been replaced
# - [x] Ran **Restart & Run All** before exporting
# - [x] Downloaded as `.ipynb` and uploaded to Canvas
